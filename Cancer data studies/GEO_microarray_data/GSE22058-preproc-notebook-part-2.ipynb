# %% [markdown]
# ## GSE22058-GPL10457 part 2 (human hepatocellular carcinoma, download of raw sample data)
# The script allows to pre-process **GSE22058-GPL10457** raw sample data acquired from GEO data base.
# <br>
# <br>
# **GSE22058-GPL10457** data set consists of 194 samples:
#
# * 96 positive samples,
# * and 96 negative samples (adjacent to the positive).
# <br>
#
# **For detailed information please refer to:** https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE22058
# <br>
#
# **Related publication:**
# <br>
# Burchard J, Zhang C, Liu AM, Poon RT et al. microRNA-122 as a regulator of mitochondrial metabolic gene network in hepatocellular carcinoma. Mol Syst Biol 2010 Aug 24;6:402. (DOI: 10.1038/msb.2010.58)
#
# **Before you start:**
# * This code is writen in **Python 3**.
# * **Required libraries**: *urllib*, *pandas*, *os*
#
# The code is written by @MelaniaNowicka, Free University of Berlin (contact: melania.nowicka@gmail.com).

# %% [markdown]
# **Import necessary libraries**

# %%
# import required libraries
from urllib import request
import pandas as pd
import os

# %% [markdown]
# **Download of separate samples from** https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE22058

# %%
path = os.getcwd()  # path to files

# get GSM ids and ids to create urls, add GSM accession ids at 'acc=' and numerical ids at 'id='
url = "https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?view=data&acc=&id=&db=GeoDb_blob46"  # general url
url_ids = pd.read_csv(os.path.join(path, "GSE22058_url_ids.csv"), sep=";")  # read file containing the ids
acc_list = list(url_ids.GSM_id)  # GSM accession ids
ids_list = list(url_ids.id)  # numerical ids

try:
     os.mkdir(os.path.join(path, os.path.normpath("html")))
except OSError:
    print ("Creation of the directory %s failed" % path)
else:
    print ("Successfully created the directory %s " % path)

# create urls, write them to files and download single sample files
with open(os.path.join(path, "GSE22058_urls.txt"), 'a+') as output:
    for i in range(0, len(acc_list)):
        print("Downloading sample: ", i+1)
        temp_url = url.replace("acc=", "acc="+acc_list[i])
        temp_url = temp_url.replace("id=", "id="+str(ids_list[i]))
        output.write(temp_url+"\n")
        request.urlretrieve(temp_url, os.path.join(path, "html/GSE22058_"+acc_list[i]))  # download sample file
# Out:
# Creation of the directory C:\Users\melan\PycharmProjects\RAccoon\Cancer data studies\GEO_microarray_data failed
# Downloading sample:  1
# Downloading sample:  2
# Downloading sample:  3
# Downloading sample:  4
# Downloading sample:  5
# Downloading sample:  6
# Downloading sample:  7
# Downloading sample:  8
# Downloading sample:  9
# Downloading sample:  10
# Downloading sample:  11
# Downloading sample:  12
# Downloading sample:  13
# Downloading sample:  14
# Downloading sample:  15
# Downloading sample:  16
# Downloading sample:  17
# Downloading sample:  18
# Downloading sample:  19
# Downloading sample:  20
# Downloading sample:  21
# Downloading sample:  22
# Downloading sample:  23
# Downloading sample:  24
# Downloading sample:  25
# Downloading sample:  26
# Downloading sample:  27
# Downloading sample:  28
# Downloading sample:  29
# Downloading sample:  30
# Downloading sample:  31
# Downloading sample:  32
# Downloading sample:  33
# Downloading sample:  34
# Downloading sample:  35
# Downloading sample:  36
# Downloading sample:  37
# Downloading sample:  38
# Downloading sample:  39
# Downloading sample:  40
# Downloading sample:  41
# Downloading sample:  42
# Downloading sample:  43
# Downloading sample:  44
# Downloading sample:  45
# Downloading sample:  46
# Downloading sample:  47
# Downloading sample:  48
# Downloading sample:  49
# Downloading sample:  50
# Downloading sample:  51
# Downloading sample:  52
# Downloading sample:  53
# Downloading sample:  54
# Downloading sample:  55
# Downloading sample:  56
# Downloading sample:  57
# Downloading sample:  58
# Downloading sample:  59
# Downloading sample:  60
# Downloading sample:  61
# Downloading sample:  62
# Downloading sample:  63
# Downloading sample:  64
# Downloading sample:  65
# Downloading sample:  66
# Downloading sample:  67
# Downloading sample:  68
# Downloading sample:  69
# Downloading sample:  70
# Downloading sample:  71
# Downloading sample:  72
# Downloading sample:  73
# Downloading sample:  74
# Downloading sample:  75
# Downloading sample:  76
# Downloading sample:  77
# Downloading sample:  78
# Downloading sample:  79
# Downloading sample:  80
# Downloading sample:  81
# Downloading sample:  82
# Downloading sample:  83
# Downloading sample:  84
# Downloading sample:  85
# Downloading sample:  86
# Downloading sample:  87
# Downloading sample:  88
# Downloading sample:  89
# Downloading sample:  90
# Downloading sample:  91
# Downloading sample:  92
# Downloading sample:  93
# Downloading sample:  94
# Downloading sample:  95
# Downloading sample:  96
# Downloading sample:  97
# Downloading sample:  98
# Downloading sample:  99
# Downloading sample:  100
# Downloading sample:  101
# Downloading sample:  102
# Downloading sample:  103
# Downloading sample:  104
# Downloading sample:  105
# Downloading sample:  106
# Downloading sample:  107
# Downloading sample:  108
# Downloading sample:  109
# Downloading sample:  110
# Downloading sample:  111
# Downloading sample:  112
# Downloading sample:  113
# Downloading sample:  114
# Downloading sample:  115
# Downloading sample:  116
# Downloading sample:  117
# Downloading sample:  118
# Downloading sample:  119
# Downloading sample:  120
# Downloading sample:  121
# Downloading sample:  122
# Downloading sample:  123
# Downloading sample:  124
# Downloading sample:  125
# Downloading sample:  126
# Downloading sample:  127
# Downloading sample:  128
# Downloading sample:  129
# Downloading sample:  130
# Downloading sample:  131
# Downloading sample:  132
# Downloading sample:  133
# Downloading sample:  134
# Downloading sample:  135
# Downloading sample:  136
# Downloading sample:  137
# Downloading sample:  138
# Downloading sample:  139
# Downloading sample:  140
# Downloading sample:  141
# Downloading sample:  142
# Downloading sample:  143
# Downloading sample:  144
# Downloading sample:  145
# Downloading sample:  146
# Downloading sample:  147
# Downloading sample:  148
# Downloading sample:  149
# Downloading sample:  150
# Downloading sample:  151
# Downloading sample:  152
# Downloading sample:  153
# Downloading sample:  154
# Downloading sample:  155
# Downloading sample:  156
# Downloading sample:  157
# Downloading sample:  158
# Downloading sample:  159
# Downloading sample:  160
# Downloading sample:  161
# Downloading sample:  162
# Downloading sample:  163
# Downloading sample:  164
# Downloading sample:  165
# Downloading sample:  166
# Downloading sample:  167
# Downloading sample:  168
# Downloading sample:  169
# Downloading sample:  170
# Downloading sample:  171
# Downloading sample:  172
# Downloading sample:  173
# Downloading sample:  174
# Downloading sample:  175
# Downloading sample:  176
# Downloading sample:  177
# Downloading sample:  178
# Downloading sample:  179
# Downloading sample:  180
# Downloading sample:  181
# Downloading sample:  182
# Downloading sample:  183
# Downloading sample:  184
# Downloading sample:  185
# Downloading sample:  186
# Downloading sample:  187
# Downloading sample:  188
# Downloading sample:  189
# Downloading sample:  190
# Downloading sample:  191
# Downloading sample:  192

# %% [markdown]
# **Pre-process sample files to create two data sets: normalized and non-normalized data set**

# %%
# process sample files
header = ["ID_REF", "RAW_VALUE", "VALUE", "PVALUE"]  # create data header (original GEO header)
raw_values = pd.DataFrame.from_dict(data={})  # create empty data frame for raw values
#normalized_values = pd.DataFrame.from_dict(data={})  # create empty data frame for normalized values
web_mir_ids = []  # list of miRNA ids from web page
i = 0  # sample counter

# read and pre-process samples
for filename in os.listdir(os.path.join(path, "html/")):  # iterate over files
    print("Processing file: ", filename)

    # strip and separate file lines
    with open(os.path.join(path, "html/")+filename) as f:
        lines = [line.rstrip() for line in f]  # strip lines
    sample = lines[24:244]  # get sample-related lines (rest is html code)

    sample_split = [line.split("\t") for line in sample]  # split sample data by tab
    sample_split_df = pd.DataFrame(sample_split, columns=header)  # and create data frame

    if i == 0:  # if this is the first sample get the miRNA ids as template
        web_mir_ids = [row[0] for row in sample_split]
        raw_values["miR_IDS"] = web_mir_ids
        #print("miRNA IDs added!")
    else:  # if not just get the miRNA ids from the new file
        temp_ids = [row[0] for row in sample_split]
        if temp_ids != web_mir_ids:  # and compare with the template
            print("IDs do not match for sample:" + str(i) + "!")  # the ids must be identical for all the files

    # create raw value data sets
    temp_raw_values = [row[1] for row in sample_split]  # get the raw sample values
    #temp_normalized_values = [row[2] for row in sample_split]  # get the normalized sample values
    raw_values[acc_list[i]] = temp_raw_values  # assign the raw values as a column with the sample accession number
    #normalized_values[acc_list[i]] = temp_normalized_values  # same for the normalized values
    i += 1  # count samples

    # save sample file
    filename_temp = filename + ".csv"
    sample_split_df.to_csv(path_or_buf=os.path.join(path, "html/", filename_temp), sep=';', index=False)
# Out:
# Processing file:  GSE22058_GSM548041
# Processing file:  GSE22058_GSM548042
# Processing file:  GSE22058_GSM548043
# Processing file:  GSE22058_GSM548044
# Processing file:  GSE22058_GSM548045
# Processing file:  GSE22058_GSM548046
# Processing file:  GSE22058_GSM548047
# Processing file:  GSE22058_GSM548048
# Processing file:  GSE22058_GSM548049
# Processing file:  GSE22058_GSM548050
# Processing file:  GSE22058_GSM548051
# Processing file:  GSE22058_GSM548052
# Processing file:  GSE22058_GSM548053
# Processing file:  GSE22058_GSM548054
# Processing file:  GSE22058_GSM548055
# Processing file:  GSE22058_GSM548056
# Processing file:  GSE22058_GSM548057
# Processing file:  GSE22058_GSM548058
# Processing file:  GSE22058_GSM548059
# Processing file:  GSE22058_GSM548060
# Processing file:  GSE22058_GSM548061
# Processing file:  GSE22058_GSM548062
# Processing file:  GSE22058_GSM548063
# Processing file:  GSE22058_GSM548064
# Processing file:  GSE22058_GSM548065
# Processing file:  GSE22058_GSM548066
# Processing file:  GSE22058_GSM548067
# Processing file:  GSE22058_GSM548068
# Processing file:  GSE22058_GSM548069
# Processing file:  GSE22058_GSM548070
# Processing file:  GSE22058_GSM548071
# Processing file:  GSE22058_GSM548072
# Processing file:  GSE22058_GSM548073
# Processing file:  GSE22058_GSM548074
# Processing file:  GSE22058_GSM548077
# Processing file:  GSE22058_GSM548078
# Processing file:  GSE22058_GSM548079
# Processing file:  GSE22058_GSM548080
# Processing file:  GSE22058_GSM548081
# Processing file:  GSE22058_GSM548082
# Processing file:  GSE22058_GSM548083
# Processing file:  GSE22058_GSM548084
# Processing file:  GSE22058_GSM548085
# Processing file:  GSE22058_GSM548086
# Processing file:  GSE22058_GSM548087
# Processing file:  GSE22058_GSM548088
# Processing file:  GSE22058_GSM548089
# Processing file:  GSE22058_GSM548090
# Processing file:  GSE22058_GSM548091
# Processing file:  GSE22058_GSM548092
# Processing file:  GSE22058_GSM548093
# Processing file:  GSE22058_GSM548094
# Processing file:  GSE22058_GSM548095
# Processing file:  GSE22058_GSM548096
# Processing file:  GSE22058_GSM548097
# Processing file:  GSE22058_GSM548098
# Processing file:  GSE22058_GSM548099
# Processing file:  GSE22058_GSM548100
# Processing file:  GSE22058_GSM548101
# Processing file:  GSE22058_GSM548102
# Processing file:  GSE22058_GSM548103
# Processing file:  GSE22058_GSM548104
# Processing file:  GSE22058_GSM548105
# Processing file:  GSE22058_GSM548106
# Processing file:  GSE22058_GSM548107
# Processing file:  GSE22058_GSM548108
# Processing file:  GSE22058_GSM548109
# Processing file:  GSE22058_GSM548110
# Processing file:  GSE22058_GSM548111
# Processing file:  GSE22058_GSM548112
# Processing file:  GSE22058_GSM548113
# Processing file:  GSE22058_GSM548114
# Processing file:  GSE22058_GSM548115
# Processing file:  GSE22058_GSM548116
# Processing file:  GSE22058_GSM548117
# Processing file:  GSE22058_GSM548118
# Processing file:  GSE22058_GSM548119
# Processing file:  GSE22058_GSM548120
# Processing file:  GSE22058_GSM548121
# Processing file:  GSE22058_GSM548122
# Processing file:  GSE22058_GSM548123
# Processing file:  GSE22058_GSM548124
# Processing file:  GSE22058_GSM548125
# Processing file:  GSE22058_GSM548126
# Processing file:  GSE22058_GSM548127
# Processing file:  GSE22058_GSM548128
# Processing file:  GSE22058_GSM548129
# Processing file:  GSE22058_GSM548130
# Processing file:  GSE22058_GSM548131
# Processing file:  GSE22058_GSM548132
# Processing file:  GSE22058_GSM548133
# Processing file:  GSE22058_GSM548134
# Processing file:  GSE22058_GSM548135
# Processing file:  GSE22058_GSM548136
# Processing file:  GSE22058_GSM548137
# Processing file:  GSE22058_GSM548138
# Processing file:  GSE22058_GSM548139
# Processing file:  GSE22058_GSM548140
# Processing file:  GSE22058_GSM548141
# Processing file:  GSE22058_GSM548142
# Processing file:  GSE22058_GSM548143
# Processing file:  GSE22058_GSM548144
# Processing file:  GSE22058_GSM548145
# Processing file:  GSE22058_GSM548146
# Processing file:  GSE22058_GSM548147
# Processing file:  GSE22058_GSM548148
# Processing file:  GSE22058_GSM548149
# Processing file:  GSE22058_GSM548150
# Processing file:  GSE22058_GSM548151
# Processing file:  GSE22058_GSM548152
# Processing file:  GSE22058_GSM548153
# Processing file:  GSE22058_GSM548154
# Processing file:  GSE22058_GSM548155
# Processing file:  GSE22058_GSM548156
# Processing file:  GSE22058_GSM548157
# Processing file:  GSE22058_GSM548158
# Processing file:  GSE22058_GSM548159
# Processing file:  GSE22058_GSM548160
# Processing file:  GSE22058_GSM548161
# Processing file:  GSE22058_GSM548162
# Processing file:  GSE22058_GSM548163
# Processing file:  GSE22058_GSM548164
# Processing file:  GSE22058_GSM548165
# Processing file:  GSE22058_GSM548166
# Processing file:  GSE22058_GSM548167
# Processing file:  GSE22058_GSM548168
# Processing file:  GSE22058_GSM548169
# Processing file:  GSE22058_GSM548170
# Processing file:  GSE22058_GSM548171
# Processing file:  GSE22058_GSM548172
# Processing file:  GSE22058_GSM548173
# Processing file:  GSE22058_GSM548174
# Processing file:  GSE22058_GSM548175
# Processing file:  GSE22058_GSM548176
# Processing file:  GSE22058_GSM548177
# Processing file:  GSE22058_GSM548178
# Processing file:  GSE22058_GSM548179
# Processing file:  GSE22058_GSM548180
# Processing file:  GSE22058_GSM548181
# Processing file:  GSE22058_GSM548182
# Processing file:  GSE22058_GSM548183
# Processing file:  GSE22058_GSM548184
# Processing file:  GSE22058_GSM548185
# Processing file:  GSE22058_GSM548186
# Processing file:  GSE22058_GSM548187
# Processing file:  GSE22058_GSM548188
# Processing file:  GSE22058_GSM548189
# Processing file:  GSE22058_GSM548190
# Processing file:  GSE22058_GSM548191
# Processing file:  GSE22058_GSM548192
# Processing file:  GSE22058_GSM548193
# Processing file:  GSE22058_GSM548194
# Processing file:  GSE22058_GSM548195
# Processing file:  GSE22058_GSM548196
# Processing file:  GSE22058_GSM548197
# Processing file:  GSE22058_GSM548198
# Processing file:  GSE22058_GSM548199
# Processing file:  GSE22058_GSM548200
# Processing file:  GSE22058_GSM548201
# Processing file:  GSE22058_GSM548202
# Processing file:  GSE22058_GSM548203
# Processing file:  GSE22058_GSM548204
# Processing file:  GSE22058_GSM548205
# Processing file:  GSE22058_GSM548206
# Processing file:  GSE22058_GSM548207
# Processing file:  GSE22058_GSM548208
# Processing file:  GSE22058_GSM548209
# Processing file:  GSE22058_GSM548210
# Processing file:  GSE22058_GSM548211
# Processing file:  GSE22058_GSM548212
# Processing file:  GSE22058_GSM548213
# Processing file:  GSE22058_GSM548214
# Processing file:  GSE22058_GSM548215
# Processing file:  GSE22058_GSM548216
# Processing file:  GSE22058_GSM548217
# Processing file:  GSE22058_GSM548218
# Processing file:  GSE22058_GSM548219
# Processing file:  GSE22058_GSM548220
# Processing file:  GSE22058_GSM548221
# Processing file:  GSE22058_GSM548222
# Processing file:  GSE22058_GSM548223
# Processing file:  GSE22058_GSM548224
# Processing file:  GSE22058_GSM548225
# Processing file:  GSE22058_GSM548226
# Processing file:  GSE22058_GSM548227
# Processing file:  GSE22058_GSM548228
# Processing file:  GSE22058_GSM548229
# Processing file:  GSE22058_GSM548230
# Processing file:  GSE22058_GSM548231
# Processing file:  GSE22058_GSM548232
# Processing file:  GSE22058_GSM548338
# Processing file:  GSE22058_GSM548339

# %% [markdown]
# **Compare downloaded samples with series matrix**

# %%
# read sample order and annotation
sample_order_and_annot = pd.read_csv(path+"/GSE22058_sample_info.csv", sep=";")

# create dictionaries translating from gsm id to int id and gsm id to annotation
gsm_to_id = dict(zip(sample_order_and_annot.original_ids, sample_order_and_annot.new_ids))
gsm_to_annot = dict(zip(sample_order_and_annot.original_ids, sample_order_and_annot.annotation))

# compare miRNA IDs from GPL platform and sample web page
# web_mir_ids = [int(i) for i in web_mir_ids]
# if list(mirna_ids.ID) == web_mir_ids:
#     print("miRNA ids are complete and identical.")
# else:
#    print("miRNA ids are incomplete, in wrong order or not identical!")
#    print(set(list(mirna_ids.ID)) - set(web_mir_ids))

# compare platform IDs from series matrix (file created in R using GEOquery) with the sample web page
mirna_ids_from_sm = pd.read_csv(path+"/mir_ids_from_series_matrix.csv", sep=";")
web_mir_ids = [int(i) for i in web_mir_ids]  # convert from string to int
if list(mirna_ids_from_sm.platform_ID) == web_mir_ids:
    print("miRNA ids are complete and identical.")
else:  # if not complete or not not identical show which ones differ
    print("miRNA ids are incomplete, in wrong order or not identical!")
    print(set(list(mirna_ids_from_sm.platform_ID)) - set(web_mir_ids))
# Out:
# miRNA ids are complete and identical.

# %% [markdown]
# **Create raw-value data set**

# %%
# create raw values dataset with the order "ID", "Annots", "mir1", "mir2", etc.
header = ["ID", "Annots"] + list(mirna_ids_from_sm.miR_ID)
raw_dataset = pd.DataFrame(columns=header)
list_of_sample_dicts = []
for sample in list(raw_values.columns[1:]):  # iterate over samples
    sample_dict = dict(zip(header, [gsm_to_id[sample], gsm_to_annot[sample]]+list(raw_values[sample])))
    list_of_sample_dicts.append(sample_dict)

# create data set and sort by ID
raw_dataset = pd.DataFrame(list_of_sample_dicts)
raw_dataset = raw_dataset.sort_values("ID", axis=0)

# normalized data was preprocessed only for comparison to series matrix purpose
# create normalized values dataset with the order "ID", "Annots", "mir1", "mir2", etc.
#normalized_dataset_web = pd.DataFrame(columns=header)  # create empty data frame
#list_of_sample_dicts = []
#for sample in list(normalized_values.columns):  # iterate over samples
#    values = [str(i).rstrip('0') for i in list(normalized_values[sample])]
#    sample_dict = dict(zip(header, [gsm_to_id[sample], gsm_to_annot[sample]]+values))
#    list_of_sample_dicts.append(sample_dict)

# create data set and sort by ID
#normalized_dataset_web = pd.DataFrame(list_of_sample_dicts)
#normalized_dataset_web = normalized_dataset_web.sort_values("ID", axis=0)

# raw_dataset.to_csv(path_or_buf=os.path.join(path, "samples/")+"GSE22058_non_norm_non_filter.csv", sep=';',
# index=False)

# normalized_dataset_web.to_csv(path_or_buf=os.path.join(path, "samples/")+"GSE22058_norm_non_filter.csv", sep=';',
# index=False)

# %% [markdown]
# **Remove non-human and *-miRNAs**

# %%
# filter * and non-human miRNAs from the header
header = [i for i in header if "*" not in i]
header = [i for i in header if "hsa" in i]
header = ["ID", "Annots"] + header

# filter data sets using the filtered header
raw_dataset_filtered = raw_dataset[header]
#normalized_dataset_web_filtered = normalized_dataset_web[header]
# Out:
# 222
# 212
# 210

# %% [markdown]
# **Save raw data set to .csv**

# %%
raw_dataset_filtered.to_csv(path_or_buf=path+"/GSE22058_non_norm_formatted.csv", sep=';',
                            index=False)
# normalized_dataset_web_filtered.to_csv(path_or_buf=os.path.join(path, "samples/")+"GSE22058_norm_formatted.csv", sep=';', index=False)
